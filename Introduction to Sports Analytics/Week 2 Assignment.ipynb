# %% [markdown]
# ## Part 1- Data Coding and Merging

# %%
#Import Libraries

import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import NHL Team Data and Display
NHL_Team=pd.read_csv("Assignment Data/Week 2/NHL_team.csv")
display(NHL_Team)
# Out:
#     Unnamed: 0    tid                   name           tname         lname  \
# 0            1      1    Toronto Maple Leafs     Maple Leafs       Toronto
# 1            2      2     Montréal Canadiens       Canadiens      Montréal
# 2            3      4          Winnipeg Jets            Jets      Winnipeg
# 3            4      5    Washington Capitals        Capitals    Washington
# 4            5      6     Chicago Blackhawks      Blackhawks       Chicago
# 5            6      7        St. Louis Blues           Blues     St. Louis
# 6            7      8    Pittsburgh Penguins        Penguins    Pittsburgh
# 7            8     10        Edmonton Oilers          Oilers      Edmonton
# 8            9     11         Calgary Flames          Flames       Calgary
# 9           10     14    Philadelphia Flyers          Flyers  Philadelphia
# 10          11     16        San Jose Sharks          Sharks      San Jose
# 11          12     17         Buffalo Sabres          Sabres       Buffalo
# 12          13     18      Detroit Red Wings       Red Wings       Detroit
# 13          14     19    Nashville Predators       Predators     Nashville
# 14          15     20          Boston Bruins          Bruins        Boston
# 15          16     21          Anaheim Ducks           Ducks       Anaheim
# 16          17     22     Colorado Avalanche       Avalanche      Colorado
# 17          18     25    Tampa Bay Lightning       Lightning     Tampa Bay
# 18          19     28       New York Rangers         Rangers      New York
# 19          20     29      New Jersey Devils          Devils    New Jersey
# 20          21     32        Ottawa Senators        Senators        Ottawa
# 21          22     35         Minnesota Wild            Wild     Minnesota
# 22          23     41      Los Angeles Kings           Kings   Los Angeles
# 23          24     43        Arizona Coyotes         Coyotes       Arizona
# 24          25     45       Florida Panthers        Panthers       Florida
# 25          26     46           Dallas Stars           Stars        Dallas
# 26          27     50        Phoenix Coyotes         Coyotes       Phoenix
# 27          28     51     New York Islanders       Islanders      New York
# 28          29     52  Columbus Blue Jackets    Blue Jackets      Columbus
# 29          30     53      Vancouver Canucks         Canucks     Vancouver
# 30          31     59   Vegas Golden Knights  Golden Knights         Vegas
# 31          32     66    Carolina Hurricanes      Hurricanes      Carolina
# 32          33  11366      Atlanta Thrashers       Thrashers       Atlanta
#
#    tricode abbr         sname
# 0      TOR  TOR       Toronto
# 1      MTL  MTL      Montréal
# 2      WPG  WPG      Winnipeg
# 3      WSH  WSH    Washington
# 4      CHI  CHI       Chicago
# 5      STL  STL      St Louis
# 6      PIT  PIT    Pittsburgh
# 7      EDM  EDM      Edmonton
# 8      CGY  CGY       Calgary
# 9      PHI  PHI  Philadelphia
# 10     SJS  SJS      San Jose
# 11     BUF  BUF       Buffalo
# 12     DET  DET       Detroit
# 13     NSH  NSH     Nashville
# 14     BOS  BOS        Boston
# 15     ANA  ANA       Anaheim
# 16     COL  COL      Colorado
# 17     TBL  TBL     Tampa Bay
# 18     NYR  NYR    NY Rangers
# 19     NJD  NJD    New Jersey
# 20     OTT  OTT        Ottawa
# 21     MIN  MIN     Minnesota
# 22     LAK  LAK   Los Angeles
# 23     ARI  ARI       Arizona
# 24     FLA  FLA       Florida
# 25     DAL  DAL        Dallas
# 26     PHX  PHX       Phoenix
# 27     NYI  NYI  NY Islanders
# 28     CBJ  CBJ      Columbus
# 29     VAN  VAN     Vancouver
# 30     VGK  VGK         Vegas
# 31     CAR  CAR      Carolina
# 32     ATL  ATL       Atlanta

# %%
#Import NHL Competition Data and Display Head
NHL_Competition=pd.read_csv("Assignment Data/Week 2/NHL_competition.csv")
NHL_Competition.head()
# Out:
#    Unnamed: 0  comp_id  year  type                     name  tz  start  end
# 0           1        1  2013     2  2013 NHL Regular Season  ET    NaN  NaN
# 1           2        2  2017     2  2017 NHL Regular Season  ET    NaN  NaN
# 2           3     2453  2013     3         2013 NHL Playoff  ET    NaN  NaN
# 3           4     2541  2017     3         2017 NHL Playoff  ET    NaN  NaN
# 4           5     2661  2012     2  2012 NHL Regular Season  ET    NaN  NaN

# %%
#Import NHL Game Data and Display Head
NHL_Game=pd.read_csv("Assignment Data/Week 2/NHL_game.csv")
NHL_Game.head()
# Out:
#    X  gid  comp_id        date  ascore  hscore  period  status home_away  tid
# 0  1   37        2   10/7/2017     NaN     NaN     NaN     NaN      away   25
# 1  2   67        2   10/9/2017     NaN     NaN     NaN     NaN      away   29
# 2  3  154        1  10/14/2013     NaN     NaN     NaN     NaN      away   29
# 3  4  278        1  10/24/2013     NaN     NaN     NaN     NaN      away   53
# 4  5  291        1  10/25/2013     NaN     NaN     NaN     NaN      away    5

# %%
#Import NHL PPPK Data and Display Head
NHL_PPPK=pd.read_csv("Assignment Data/Week 2/pp.pk.ppgf.csv")
NHL_PPPK.head()
# Out:
#   tricode   pp   pk  ppgf  competition_name
# 0     ANA   35   27   9.0  2010 NHL Playoff
# 1     BOS  126  116  22.0  2010 NHL Playoff
# 2     BUF   48   46  13.0  2010 NHL Playoff
# 3     CHI   27   39   6.0  2010 NHL Playoff
# 4     DET   59   55   6.0  2010 NHL Playoff

# %%
# Import the “NHL_Team.csv” data file and name the dataframe as “NHL_Team” in Jupyter Notebook.
# a) Delete the following variables: “Unnamed:0”, “abbr”, “tname”, “lname”, and “sname”.
# b) Rename the variable “name” to “team_name”
NHL_Team.drop(['Unnamed: 0', 'abbr', 'tname', 'lname', 'sname'], axis=1, inplace=True)
NHL_Team.rename(columns={'name':'team_name'}, inplace=True)
NHL_Team
# Out:
#       tid              team_name tricode
# 0       1    Toronto Maple Leafs     TOR
# 1       2     Montréal Canadiens     MTL
# 2       4          Winnipeg Jets     WPG
# 3       5    Washington Capitals     WSH
# 4       6     Chicago Blackhawks     CHI
# 5       7        St. Louis Blues     STL
# 6       8    Pittsburgh Penguins     PIT
# 7      10        Edmonton Oilers     EDM
# 8      11         Calgary Flames     CGY
# 9      14    Philadelphia Flyers     PHI
# 10     16        San Jose Sharks     SJS
# 11     17         Buffalo Sabres     BUF
# 12     18      Detroit Red Wings     DET
# 13     19    Nashville Predators     NSH
# 14     20          Boston Bruins     BOS
# 15     21          Anaheim Ducks     ANA
# 16     22     Colorado Avalanche     COL
# 17     25    Tampa Bay Lightning     TBL
# 18     28       New York Rangers     NYR
# 19     29      New Jersey Devils     NJD
# 20     32        Ottawa Senators     OTT
# 21     35         Minnesota Wild     MIN
# 22     41      Los Angeles Kings     LAK
# 23     43        Arizona Coyotes     ARI
# 24     45       Florida Panthers     FLA
# 25     46           Dallas Stars     DAL
# 26     50        Phoenix Coyotes     PHX
# 27     51     New York Islanders     NYI
# 28     52  Columbus Blue Jackets     CBJ
# 29     53      Vancouver Canucks     VAN
# 30     59   Vegas Golden Knights     VGK
# 31     66    Carolina Hurricanes     CAR
# 32  11366      Atlanta Thrashers     ATL

# %%
# Import the “NHL_competition.csv” data file and name the dataframe as “NHL_Competition” in Jupyter Notebook.
# a) Delete the following variables: “Unnamed: 0”, “tz”, “start”, and “end”
# b) Rename the variable “name” to “competition_name”.

NHL_Competition.drop(['Unnamed: 0', 'tz', 'start', 'end'], axis=1, inplace=True)
NHL_Competition.rename(columns={'name':'competition_name'}, inplace=True)
NHL_Competition
# Out:
#     comp_id  year  type         competition_name
# 0         1  2013     2  2013 NHL Regular Season
# 1         2  2017     2  2017 NHL Regular Season
# 2      2453  2013     3         2013 NHL Playoff
# 3      2541  2017     3         2017 NHL Playoff
# 4      2661  2012     2  2012 NHL Regular Season
# 5      2734  2016     2  2016 NHL Regular Season
# 6      4099  2012     3         2012 NHL Playoff
# 7      4287  2011     2  2011 NHL Regular Season
# 8      5181  2016     3         2016 NHL Playoff
# 9      5385  2015     2  2015 NHL Regular Season
# 10     5478  2011     3         2011 NHL Playoff
# 11     5662  2010     2  2010 NHL Regular Season
# 12     7813  2015     3         2015 NHL Playoff
# 13     8011  2014     2  2014 NHL Regular Season
# 14     8131  2010     3         2010 NHL Playoff
# 15     9389  2014     3         2014 NHL Playoff

# %%
# Import the “NHL_game.csv” data file and name the dataframe as “NHL_Game” in Jupyter Notebook.
# a) Delete the following variables: “X”, “period”, and “status”.
NHL_Game.drop(['X', 'period', 'status'], axis=1, inplace=True)
NHL_Game
# Out:
#         gid  comp_id        date  ascore  hscore home_away  tid
# 0        37        2   10/7/2017     NaN     NaN      away   25
# 1        67        2   10/9/2017     NaN     NaN      away   29
# 2       154        1  10/14/2013     NaN     NaN      away   29
# 3       278        1  10/24/2013     NaN     NaN      away   53
# 4       291        1  10/25/2013     NaN     NaN      away    5
# 5       294        1  10/25/2013     NaN     NaN      away   51
# 6       396        2   11/3/2017     NaN     NaN      away   17
# 7       402        2   11/4/2017     NaN     NaN      away   19
# 8       421        2   11/5/2017     NaN     NaN      away   66
# 9       518        1  11/11/2013     NaN     NaN      away   53
# 10      528        2  11/13/2017     NaN     NaN      away   29
# 11      600        1  11/17/2013     NaN     NaN      away   10
# 12      622        2  11/20/2017     NaN     NaN      away   45
# 13      640        2  11/22/2017     NaN     NaN      away    2
# 14      673        1  11/23/2013     NaN     NaN      away   45
# 15      741        1  11/28/2013     NaN     NaN      away    1
# 16      782        1   12/1/2013     NaN     NaN      away    1
# 17      794        2   12/2/2017     NaN     NaN      away   59
# 18      825        2   12/4/2017     NaN     NaN      away   46
# 19      857        1   12/7/2013     NaN     NaN      away   18
# 20      921        2  12/11/2017     NaN     NaN      away   17
# 21      966        2  12/15/2017     NaN     NaN      away   51
# 22      992        1  12/15/2013     NaN     NaN      away   14
# 23     1036        2  12/19/2017     NaN     NaN      away   66
# 24     1083        2  12/23/2017     NaN     NaN      away   35
# 25     1272        1    1/6/2014     NaN     NaN      away   19
# 26     1282        2    1/7/2018     NaN     NaN      away   28
# 27     1337        1   1/11/2014     NaN     NaN      away   51
# 28     1351        2   1/14/2018     NaN     NaN      away    4
# 29     1419        1   1/17/2014     NaN     NaN      away   51
# ...     ...      ...         ...     ...     ...       ...  ...
# 18916  8934     8011    2/8/2015     0.0     1.0      home   35
# 18917  8355     8011   11/8/2014     4.0     3.0      home   21
# 18918  5944     5662  10/30/2010     7.0     4.0      home    6
# 18919   122        1  10/12/2013     2.0     3.0      home    6
# 18920  7261     5662    2/6/2011     0.0     1.0      home   50
# 18921  9397     9389   4/29/2015     0.0     2.0      home   25
# 18922  3510     2734   12/7/2016     3.0     4.0      home   19
# 18923  3022     2661   2/13/2013     3.0     2.0      home    4
# 18924   648        1  11/22/2013     4.0     3.0      home   20
# 18925   570        1  11/16/2013     3.0     4.0      home   66
# 18926  9137     8011    3/8/2015     6.0     7.0      home   32
# 18927  1014        2  12/17/2017     6.0     5.0      home   22
# 18928   530        1  11/13/2013     1.0     2.0      home   66
# 18929   536        1  11/13/2013     4.0     3.0      home   18
# 18930  6982     5662   1/14/2011     3.0     1.0      home   41
# 18931  6571     5662  12/16/2010     2.0     3.0      home   17
# 18932  8524     8011   12/3/2014     1.0     2.0      home   16
# 18933  7004     5385   2/14/2016     5.0     0.0      home   45
# 18934  9098     8011    3/4/2015     5.0     3.0      home   52
# 18935  6107     5662  11/12/2010     2.0     6.0      home   18
# 18936  4035     2661   4/24/2013     2.0     5.0      home   25
# 18937    55        1   10/6/2013     1.0     2.0      home   46
# 18938  4617     4287   11/3/2011     4.0     1.0      home   22
# 18939  3858     2661   4/12/2013     2.0     0.0      home   35
# 18940  9180     8011   3/15/2015     3.0     1.0      home    7
# 18941  4827     4287  11/19/2011     0.0     3.0      home   22
# 18942  7227     5662    2/4/2011     2.0     3.0      home   14
# 18943   790        2   12/2/2017     2.0     1.0      home   45
# 18944  2850     2734  10/21/2016     4.0     2.0      home   11
# 18945  5642     5385  10/29/2015     3.0     1.0      home    5
#
# [18946 rows x 7 columns]

# %%
# Merge the dataframe “NHL_Team” into the dataframe “NHL_Game” by “tid.” 
# Continue to name the merged dataframe as “NHL_Game.”
NHL_Game=pd.merge(NHL_Team, NHL_Game, on=['tid'])
NHL_Game.head()
# Out:
#    tid            team_name tricode   gid  comp_id        date  ascore  \
# 0    1  Toronto Maple Leafs     TOR   741        1  11/28/2013     NaN
# 1    1  Toronto Maple Leafs     TOR   782        1   12/1/2013     NaN
# 2    1  Toronto Maple Leafs     TOR  5225     5181   4/25/2017     NaN
# 3    1  Toronto Maple Leafs     TOR  6557     5385    1/7/2016     NaN
# 4    1  Toronto Maple Leafs     TOR  6914     5385    2/7/2016     NaN
#
#    hscore home_away
# 0     NaN      away
# 1     NaN      away
# 2     NaN      away
# 3     NaN      away
# 4     NaN      away

# %%
# Merge the dataframe “NHL_Competition” into the dataframe “NHL_Game” by “comp_id.” 
# Continue to name the merged dataframe as “NHL_Game.”
NHL_Game=pd.merge(NHL_Competition, NHL_Game, on=['comp_id'])
NHL_Game.head()
# Out:
#    comp_id  year  type         competition_name  tid            team_name  \
# 0        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 1        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 2        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#   tricode   gid        date  ascore  hscore home_away
# 0     TOR   741  11/28/2013     NaN     NaN      away
# 1     TOR   782   12/1/2013     NaN     NaN      away
# 2     TOR  1003  12/17/2013     1.0     3.0      away
# 3     TOR  1552   1/26/2014     4.0     5.0      away
# 4     TOR  1811    3/2/2014     3.0     4.0      away

# %%
# In the merged “NHL_Game” dataframe, create a variable “hgd” to indicate the goal difference between home and away score 
# (hscore – ascore) and delete observations with missing value in the variable “hgd”.
NHL_Game['hgd']=NHL_Game['hscore']-NHL_Game['ascore']
NHL_Game=NHL_Game[pd.notnull(NHL_Game["hgd"])]
NHL_Game.head()
# Out:
#    comp_id  year  type         competition_name  tid            team_name  \
# 2        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#   tricode   gid        date  ascore  hscore home_away  hgd
# 2     TOR  1003  12/17/2013     1.0     3.0      away  2.0
# 3     TOR  1552   1/26/2014     4.0     5.0      away  1.0
# 4     TOR  1811    3/2/2014     3.0     4.0      away  1.0
# 5     TOR  1940   3/11/2014     3.0     1.0      away -2.0
# 6     TOR  1522   1/24/2014     1.0     7.0      away  6.0

# %%
# Drop all observations with missing values, if there is still any, from the “NHL_Game” dataframe.
NHL_Game=NHL_Game.dropna()
NHL_Game.shape
# Out:
# (18506, 13)

# %%
# Convert the type of the “date” variable from “object” to “datetime.”
import datetime
NHL_Game['date']=pd.to_datetime(NHL_Game['date'])
NHL_Game['date'].head()
# Out:
# 2   2013-12-17
# 3   2014-01-26
# 4   2014-03-02
# 5   2014-03-11
# 6   2014-01-24
# Name: date, dtype: datetime64[ns]

# %%
# Sort the NHL games by “date” and show the first 15 observations.
NHL_Game.sort_values(by=['date'], ascending=[True]).head(15)
# Out:
#        comp_id  year  type         competition_name  tid  \
# 15183     5662  2010     2  2010 NHL Regular Season   35
# 14163     5662  2010     2  2010 NHL Regular Season   14
# 15794     5662  2010     2  2010 NHL Regular Season   66
# 13955     5662  2010     2  2010 NHL Regular Season    8
# 13611     5662  2010     2  2010 NHL Regular Season    2
# 13564     5662  2010     2  2010 NHL Regular Season    1
# 14796     5662  2010     2  2010 NHL Regular Season   22
# 15675     5662  2010     2  2010 NHL Regular Season   52
# 14664     5662  2010     2  2010 NHL Regular Season   21
# 13672     5662  2010     2  2010 NHL Regular Season    5
# 15145     5662  2010     2  2010 NHL Regular Season   35
# 13770     5662  2010     2  2010 NHL Regular Season    6
# 15112     5662  2010     2  2010 NHL Regular Season   32
# 14056     5662  2010     2  2010 NHL Regular Season   10
# 14460     5662  2010     2  2010 NHL Regular Season   18
#
#                    team_name tricode   gid       date  ascore  hscore  \
# 15183         Minnesota Wild     MIN  5666 2010-10-07     4.0     3.0
# 14163    Philadelphia Flyers     PHI  5664 2010-10-07     3.0     2.0
# 15794    Carolina Hurricanes     CAR  5666 2010-10-07     4.0     3.0
# 13955    Pittsburgh Penguins     PIT  5664 2010-10-07     3.0     2.0
# 13611     Montréal Canadiens     MTL  5662 2010-10-07     2.0     3.0
# 13564    Toronto Maple Leafs     TOR  5662 2010-10-07     2.0     3.0
# 14796     Colorado Avalanche     COL  5668 2010-10-08     3.0     4.0
# 15675  Columbus Blue Jackets     CBJ  5672 2010-10-08     3.0     2.0
# 14664          Anaheim Ducks     ANA  5679 2010-10-08     0.0     4.0
# 13672    Washington Capitals     WSH  5683 2010-10-08     2.0     4.0
# 15145         Minnesota Wild     MIN  5677 2010-10-08     1.0     2.0
# 13770     Chicago Blackhawks     CHI  5668 2010-10-08     3.0     4.0
# 15112        Ottawa Senators     OTT  5681 2010-10-08     2.0     1.0
# 14056        Edmonton Oilers     EDM  5670 2010-10-08     0.0     4.0
# 14460      Detroit Red Wings     DET  5679 2010-10-08     0.0     4.0
#
#       home_away  hgd
# 15183      home -1.0
# 14163      away -1.0
# 15794      away -1.0
# 13955      home -1.0
# 13611      away  1.0
# 13564      home  1.0
# 14796      home  1.0
# 15675      home -1.0
# 14664      away  4.0
# 13672      away  2.0
# 15145      away  1.0
# 13770      away  1.0
# 15112      home -1.0
# 14056      home  4.0
# 14460      home  4.0

# %%
# Create two dataframes that separate the “NHL_Game” dataframe by home and away games. 
# Name them “NHL_Home” and “NHL_Away”, respectively.
# a) Rename variables:
#      i) For away games, rename “ascore” to “goals_for”; rename “hscore” to “goals_against”
#      ii) For home games, rename “hscore” to “goals_for”; rename “ascore” to “goals_against” 
# b) Create a “win” variable that equals to 1 if the team won the game; 0 if the team lost the game; 
#    and 0.5 if it was a draw. 

NHL_Home = NHL_Game[NHL_Game['home_away'] == 'home']
NHL_Home.rename(columns={'hscore':'goals_for', 'ascore': 'goals_against'}, inplace=True)
NHL_Home['win']=np.where(NHL_Home['goals_for']>NHL_Home['goals_against'], 1, np.where(NHL_Home['goals_for']==NHL_Home['goals_against'],.5,0))


NHL_Away = NHL_Game[NHL_Game['home_away'] == 'away']
NHL_Away.rename(columns={'ascore':'goals_for', 'hscore': 'goals_against'}, inplace=True)
NHL_Away['win']=np.where(NHL_Away['goals_for']>NHL_Away['goals_against'], 1, np.where(NHL_Away['goals_for']==NHL_Away['goals_against'],.5,0))

NHL_Home.head()
NHL_Away.head()
# Out:
#    comp_id  year  type         competition_name  tid            team_name  \
# 2        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#   tricode   gid       date  goals_for  goals_against home_away  hgd  win
# 2     TOR  1003 2013-12-17        1.0            3.0      away  2.0  0.0
# 3     TOR  1552 2014-01-26        4.0            5.0      away  1.0  0.0
# 4     TOR  1811 2014-03-02        3.0            4.0      away  1.0  0.0
# 5     TOR  1940 2014-03-11        3.0            1.0      away -2.0  1.0
# 6     TOR  1522 2014-01-24        1.0            7.0      away  6.0  0.0

# %%
# Append the “NHL_Home” and “NHL_Away” dataframes to be the new “NHL_Game” dataframe.
NHL_Game = pd.concat([NHL_Home, NHL_Away], axis=0).reset_index(drop=True)
NHL_Game.head()
# Out:
#    comp_id         competition_name       date   gid  goals_against  \
# 0        1  2013 NHL Regular Season 2013-10-26   307            1.0
# 1        1  2013 NHL Regular Season 2013-11-24   682            2.0
# 2        1  2013 NHL Regular Season 2014-03-25  2150            5.0
# 3        1  2013 NHL Regular Season 2014-03-19  2067            5.0
# 4        1  2013 NHL Regular Season 2014-04-03  2281            3.0
#
#    goals_for  hgd home_away            team_name  tid tricode  type  win  year
# 0        4.0  3.0      home  Toronto Maple Leafs    1     TOR     2  1.0  2013
# 1        3.0  1.0      home  Toronto Maple Leafs    1     TOR     2  1.0  2013
# 2        3.0 -2.0      home  Toronto Maple Leafs    1     TOR     2  0.0  2013
# 3        3.0 -2.0      home  Toronto Maple Leafs    1     TOR     2  0.0  2013
# 4        4.0  1.0      home  Toronto Maple Leafs    1     TOR     2  1.0  2013

# %%
# Generate a team level dataframe that aggregates the total number of games won, 
# the total number of “goals_for” and “goals_against” for each team in each competition 
# (i.e. grouped by tid, competition_name and type). Name this new dataframe “NHL_Team_Stats”. 
# Make sure to convert the indexes of the new dataframe back as  variables. 
NHL_Team_Stats = NHL_Game.groupby(['tid', 'team_name', 'competition_name', 'type', 'tricode']).agg({
    'win': 'sum',
    'goals_for': 'sum',
    'goals_against': 'sum'
}).reset_index()

NHL_Team_Stats.rename(columns={
    'win': 'total_games_won',
    'goals_for': 'total_goals_for',
    'goals_against': 'total_goals_against'
}, inplace=True)

NHL_Team_Stats.head(20)
# Out:
#     tid            team_name         competition_name  type tricode  \
# 0     1  Toronto Maple Leafs  2010 NHL Regular Season     2     TOR
# 1     1  Toronto Maple Leafs  2011 NHL Regular Season     2     TOR
# 2     1  Toronto Maple Leafs         2012 NHL Playoff     3     TOR
# 3     1  Toronto Maple Leafs  2012 NHL Regular Season     2     TOR
# 4     1  Toronto Maple Leafs  2013 NHL Regular Season     2     TOR
# 5     1  Toronto Maple Leafs  2014 NHL Regular Season     2     TOR
# 6     1  Toronto Maple Leafs  2015 NHL Regular Season     2     TOR
# 7     1  Toronto Maple Leafs         2016 NHL Playoff     3     TOR
# 8     1  Toronto Maple Leafs  2016 NHL Regular Season     2     TOR
# 9     1  Toronto Maple Leafs         2017 NHL Playoff     3     TOR
# 10    1  Toronto Maple Leafs  2017 NHL Regular Season     2     TOR
# 11    2   Montréal Canadiens         2010 NHL Playoff     3     MTL
# 12    2   Montréal Canadiens  2010 NHL Regular Season     2     MTL
# 13    2   Montréal Canadiens  2011 NHL Regular Season     2     MTL
# 14    2   Montréal Canadiens         2012 NHL Playoff     3     MTL
# 15    2   Montréal Canadiens  2012 NHL Regular Season     2     MTL
# 16    2   Montréal Canadiens         2013 NHL Playoff     3     MTL
# 17    2   Montréal Canadiens  2013 NHL Regular Season     2     MTL
# 18    2   Montréal Canadiens         2014 NHL Playoff     3     MTL
# 19    2   Montréal Canadiens  2014 NHL Regular Season     2     MTL
#
#     total_games_won  total_goals_for  total_goals_against
# 0              36.0            223.0                259.0
# 1              20.0            129.0                129.0
# 2               3.0             18.0                 22.0
# 3              25.0            144.0                129.0
# 4              38.0            231.0                250.0
# 5              29.0            209.0                258.0
# 6              29.0            196.0                238.0
# 7               2.0             16.0                 18.0
# 8              40.0            255.0                246.0
# 9               3.0             20.0                 28.0
# 10             47.0            268.0                232.0
# 11              3.0             17.0                 17.0
# 12             43.0            213.0                203.0
# 13             14.0            104.0                114.0
# 14              1.0              9.0                 20.0
# 15             29.0            152.0                129.0
# 16             10.0             51.0                 46.0
# 17             45.5            216.0                206.0
# 18              6.0             25.0                 29.0
# 19             49.0            223.0                188.0

# %%
# Create a dataframe “NHL_Game_Count” that includes the total number of games played by each team in each competition
# (i.e. grouped by tid, competition_name and type). Name this new variable in the dataframe “game_count”.

NHL_Game_Count = NHL_Game.groupby(['tid', 'team_name', 'competition_name', 'type', 'tricode']).size().reset_index(name='game_count')
NHL_Game_Count.head(20)
# Out:
#     tid            team_name         competition_name  type tricode  \
# 0     1  Toronto Maple Leafs  2010 NHL Regular Season     2     TOR
# 1     1  Toronto Maple Leafs  2011 NHL Regular Season     2     TOR
# 2     1  Toronto Maple Leafs         2012 NHL Playoff     3     TOR
# 3     1  Toronto Maple Leafs  2012 NHL Regular Season     2     TOR
# 4     1  Toronto Maple Leafs  2013 NHL Regular Season     2     TOR
# 5     1  Toronto Maple Leafs  2014 NHL Regular Season     2     TOR
# 6     1  Toronto Maple Leafs  2015 NHL Regular Season     2     TOR
# 7     1  Toronto Maple Leafs         2016 NHL Playoff     3     TOR
# 8     1  Toronto Maple Leafs  2016 NHL Regular Season     2     TOR
# 9     1  Toronto Maple Leafs         2017 NHL Playoff     3     TOR
# 10    1  Toronto Maple Leafs  2017 NHL Regular Season     2     TOR
# 11    2   Montréal Canadiens         2010 NHL Playoff     3     MTL
# 12    2   Montréal Canadiens  2010 NHL Regular Season     2     MTL
# 13    2   Montréal Canadiens  2011 NHL Regular Season     2     MTL
# 14    2   Montréal Canadiens         2012 NHL Playoff     3     MTL
# 15    2   Montréal Canadiens  2012 NHL Regular Season     2     MTL
# 16    2   Montréal Canadiens         2013 NHL Playoff     3     MTL
# 17    2   Montréal Canadiens  2013 NHL Regular Season     2     MTL
# 18    2   Montréal Canadiens         2014 NHL Playoff     3     MTL
# 19    2   Montréal Canadiens  2014 NHL Regular Season     2     MTL
#
#     game_count
# 0           82
# 1           40
# 2            7
# 3           46
# 4           79
# 5           78
# 6           79
# 7            6
# 8           82
# 9            7
# 10          79
# 11           7
# 12          79
# 13          39
# 14           5
# 15          48
# 16          17
# 17          81
# 18          12
# 19          79

# %%
# Merge dataframes.
# a) Merge the “NHL_Game_Count” dataframe into the “NHL_Team_Stats” dataframe by “tid”, “competition_name”, and “type”. 
#    Continue to name the merged dataframe “NHL_Team_Stats”.
# b) Merge the “NHL_Team” dataframe into the “NHL_Team_Stats” dataframe by “tid”. 
#    Continue to name the merged dataframe “NHL_Team_Stats”.
NHL_Team_Stats = pd.merge(NHL_Game_Count, NHL_Team_Stats, on=['tid', 'team_name', 'competition_name', 'type', 'tricode'])
#NHL_Team_Stats.drop(['game_count_y'], axis=1, inplace=True)
#NHL_Team_Stats.rename(columns={'game_count_x':'game_count'}, inplace=True)
NHL_Team_Stats.head()
# Out:
#    tid            team_name         competition_name  type tricode  \
# 0    1  Toronto Maple Leafs  2010 NHL Regular Season     2     TOR
# 1    1  Toronto Maple Leafs  2011 NHL Regular Season     2     TOR
# 2    1  Toronto Maple Leafs         2012 NHL Playoff     3     TOR
# 3    1  Toronto Maple Leafs  2012 NHL Regular Season     2     TOR
# 4    1  Toronto Maple Leafs  2013 NHL Regular Season     2     TOR
#
#    game_count  total_games_won  total_goals_for  total_goals_against
# 0          82             36.0            223.0                259.0
# 1          40             20.0            129.0                129.0
# 2           7              3.0             18.0                 22.0
# 3          46             25.0            144.0                129.0
# 4          79             38.0            231.0                250.0

# %%
# Import the “pp.pk.ppgf.csv” data file and name the dataframe as “NHL_PPPK” in Jupyter Notebook. 
# Merge the “NHL_PPPK” dataframe into the “NHL_Team_Stats” dataframe by “tricode” and “competition_name”.
NHL_PPPK=pd.read_csv("Assignment Data/Week 2/pp.pk.ppgf.csv")
NHL_Team_Stats = pd.merge(NHL_PPPK, NHL_Team_Stats, on=['tricode', 'competition_name'])
NHL_Team_Stats
# Out:
#     tricode   pp   pk  ppgf         competition_name    tid  \
# 0       ANA   35   27   9.0         2010 NHL Playoff     21
# 1       BOS  126  116  22.0         2010 NHL Playoff     20
# 2       BUF   48   46  13.0         2010 NHL Playoff     17
# 3       CHI   27   39   6.0         2010 NHL Playoff      6
# 4       DET   59   55   6.0         2010 NHL Playoff     18
# 5       LAK   24   27   5.0         2010 NHL Playoff     41
# 6       MTL   24   31   6.0         2010 NHL Playoff      2
# 7       NSH   49   60   7.0         2010 NHL Playoff     19
# 8       NYR   20   23   1.0         2010 NHL Playoff     28
# 9       PHI   70   69   5.0         2010 NHL Playoff     14
# 10      PHX   19   22   6.0         2010 NHL Playoff     50
# 11      PIT   33   40   4.0         2010 NHL Playoff      8
# 12      SJS   93   88  17.0         2010 NHL Playoff     16
# 13      TBL   80   71  10.0         2010 NHL Playoff     25
# 14      VAN  133  129  21.0         2010 NHL Playoff     53
# 15      WSH   37   34   9.0         2010 NHL Playoff      5
# 16      ANA  401  378  92.0  2010 NHL Regular Season     21
# 17      ATL  338  341  35.0  2010 NHL Regular Season  11366
# 18      BOS  368  370  74.0  2010 NHL Regular Season     20
# 19      BUF  393  364  83.0  2010 NHL Regular Season     17
# 20      CAR  338  427  79.0  2010 NHL Regular Season     66
# 21      CBJ  423  416  45.0  2010 NHL Regular Season     52
# 22      CGY  343  374  90.0  2010 NHL Regular Season     11
# 23      CHI  296  310  93.0  2010 NHL Regular Season      6
# 24      COL  390  338  61.0  2010 NHL Regular Season     22
# 25      DAL  382  416  72.0  2010 NHL Regular Season     46
# 26      DET  325  339  70.0  2010 NHL Regular Season     18
# 27      EDM  425  404  63.0  2010 NHL Regular Season     10
# 28      FLA  304  306  48.0  2010 NHL Regular Season     45
# 29      LAK  354  366  77.0  2010 NHL Regular Season     41
# ..      ...  ...  ...   ...                      ...    ...
# 339     ARI  263  291  47.0  2017 NHL Regular Season     43
# 340     BOS  308  319  72.0  2017 NHL Regular Season     20
# 341     BUF  257  278  16.0  2017 NHL Regular Season     17
# 342     CAR  218  255  51.0  2017 NHL Regular Season     66
# 343     CBJ  246  268  45.0  2017 NHL Regular Season     52
# 344     CGY  353  350  47.0  2017 NHL Regular Season     11
# 345     CHI  268  303  49.0  2017 NHL Regular Season      6
# 346     COL  305  330  67.0  2017 NHL Regular Season     22
# 347     DAL  323  304  56.0  2017 NHL Regular Season     46
# 348     DET  293  278  48.0  2017 NHL Regular Season     18
# 349     EDM  289  255  28.0  2017 NHL Regular Season     10
# 350     FLA  307  328  55.0  2017 NHL Regular Season     45
# 351     LAK  313  289  53.0  2017 NHL Regular Season     41
# 352     MIN  300  270  51.0  2017 NHL Regular Season     35
# 353     MTL  300  278  53.0  2017 NHL Regular Season      2
# 354     NJD  294  289  52.0  2017 NHL Regular Season     29
# 355     NSH  365  334  58.0  2017 NHL Regular Season     19
# 356     NYI  273  282  62.0  2017 NHL Regular Season     51
# 357     NYR  285  278  55.0  2017 NHL Regular Season     28
# 358     OTT  276  287  46.0  2017 NHL Regular Season     32
# 359     PHI  280  321  59.0  2017 NHL Regular Season     14
# 360     PIT  326  317  47.0  2017 NHL Regular Season      8
# 361     SJS  262  287  55.0  2017 NHL Regular Season     16
# 362     STL  259  281  43.0  2017 NHL Regular Season      7
# 363     TBL  319  322  72.0  2017 NHL Regular Season     25
# 364     TOR  256  245  58.0  2017 NHL Regular Season      1
# 365     VAN  299  272  63.0  2017 NHL Regular Season     53
# 366     VGK  257  273  64.0  2017 NHL Regular Season     59
# 367     WPG  307  304  69.0  2017 NHL Regular Season      4
# 368     WSH  327  297  67.0  2017 NHL Regular Season      5
#
#                  team_name  type  game_count  total_games_won  \
# 0            Anaheim Ducks     3           6              2.0
# 1            Boston Bruins     3          24             16.0
# 2           Buffalo Sabres     3           7              3.0
# 3       Chicago Blackhawks     3           7              3.0
# 4        Detroit Red Wings     3          11              7.0
# 5        Los Angeles Kings     3           5              1.0
# 6       Montréal Canadiens     3           7              3.0
# 7      Nashville Predators     3          12              6.0
# 8         New York Rangers     3           5              1.0
# 9      Philadelphia Flyers     3          11              4.0
# 10         Phoenix Coyotes     3           4              0.0
# 11     Pittsburgh Penguins     3           7              3.0
# 12         San Jose Sharks     3          17              9.0
# 13     Tampa Bay Lightning     3          16              9.0
# 14       Vancouver Canucks     3          25             15.0
# 15     Washington Capitals     3           8              4.0
# 16           Anaheim Ducks     2          78             43.5
# 17       Atlanta Thrashers     2          79             34.0
# 18           Boston Bruins     2          82             46.0
# 19          Buffalo Sabres     2          82             43.0
# 20     Carolina Hurricanes     2          82             40.0
# 21   Columbus Blue Jackets     2          81             33.5
# 22          Calgary Flames     2          80             40.5
# 23      Chicago Blackhawks     2          78             41.5
# 24      Colorado Avalanche     2          79             30.5
# 25            Dallas Stars     2          81             42.5
# 26       Detroit Red Wings     2          80             45.5
# 27         Edmonton Oilers     2          80             25.0
# 28        Florida Panthers     2          81             30.0
# 29       Los Angeles Kings     2          81             46.0
# ..                     ...   ...         ...              ...
# 339        Arizona Coyotes     2          79             28.0
# 340          Boston Bruins     2          82             51.0
# 341         Buffalo Sabres     2          76             26.0
# 342    Carolina Hurricanes     2          80             35.5
# 343  Columbus Blue Jackets     2          81             44.0
# 344         Calgary Flames     2          82             37.0
# 345     Chicago Blackhawks     2          80             33.0
# 346     Colorado Avalanche     2          80             42.0
# 347           Dallas Stars     2          79             39.0
# 348      Detroit Red Wings     2          79             29.0
# 349        Edmonton Oilers     2          80             35.0
# 350       Florida Panthers     2          78             40.5
# 351      Los Angeles Kings     2          82             45.0
# 352         Minnesota Wild     2          79             43.0
# 353     Montréal Canadiens     2          79             27.5
# 354      New Jersey Devils     2          80             42.5
# 355    Nashville Predators     2          81             52.0
# 356     New York Islanders     2          81             34.5
# 357       New York Rangers     2          80             33.0
# 358        Ottawa Senators     2          80             25.5
# 359    Philadelphia Flyers     2          81             42.0
# 360    Pittsburgh Penguins     2          82             46.0
# 361        San Jose Sharks     2          80             43.0
# 362        St. Louis Blues     2          79             42.5
# 363    Tampa Bay Lightning     2          80             54.0
# 364    Toronto Maple Leafs     2          79             47.0
# 365      Vancouver Canucks     2          81             30.0
# 366   Vegas Golden Knights     2          81             50.5
# 367          Winnipeg Jets     2          80             51.0
# 368    Washington Capitals     2          81             48.0
#
#      total_goals_for  total_goals_against
# 0               19.0                 22.0
# 1               76.0                 48.0
# 2               17.0                 22.0
# 3               22.0                 16.0
# 4               36.0                 27.0
# 5               17.0                 19.0
# 6               17.0                 17.0
# 7               33.0                 33.0
# 8                8.0                 13.0
# 9               29.0                 36.0
# 10               9.0                 18.0
# 11              14.0                 22.0
# 12              50.0                 55.0
# 13              50.0                 39.0
# 14              58.0                 69.0
# 15              21.0                 20.0
# 16             227.0                225.0
# 17             223.0                263.0
# 18             250.0                200.0
# 19             251.0                235.0
# 20             239.0                242.0
# 21             221.0                260.0
# 22             250.0                241.0
# 23             246.0                222.0
# 24             218.0                272.0
# 25             237.0                234.0
# 26             255.0                235.0
# 27             194.0                267.0
# 28             198.0                232.0
# 29             223.0                202.0
# ..               ...                  ...
# 339            204.0                251.0
# 340            274.0                217.0
# 341            182.0                247.0
# 342            227.0                248.0
# 343            242.0                232.0
# 344            223.0                255.0
# 345            225.0                248.0
# 346            251.0                228.0
# 347            226.0                223.0
# 348            212.0                249.0
# 349            231.0                263.0
# 350            237.0                240.0
# 351            242.0                205.0
# 352            248.0                230.0
# 353            205.0                258.0
# 354            240.0                242.0
# 355            268.0                215.0
# 356            261.0                293.0
# 357            234.0                268.0
# 358            220.0                295.0
# 359            251.0                244.0
# 360            271.0                249.0
# 361            257.0                235.0
# 362            223.0                215.0
# 363            293.0                226.0
# 364            268.0                232.0
# 365            219.0                268.0
# 366            269.0                223.0
# 367            274.0                214.0
# 368            255.0                240.0
#
# [369 rows x 12 columns]

# %%
# Create new variables in the “NHL_Team_Stats” dataframe.
# a) Winning percentage (“win_pct”)=”win”/ total number of games played
# b) Average goals for per game (“avg_gf”)=total number of goals for / total number of games played     
# c) Average goals against per game (“avg_ga”)=total number of goals against / total number of games played
NHL_Team_Stats['win_pct'] = NHL_Team_Stats['total_games_won']/NHL_Team_Stats['game_count']
NHL_Team_Stats['avg_gf'] = NHL_Team_Stats['total_goals_for']/NHL_Team_Stats['game_count']
NHL_Team_Stats['avg_ga'] = NHL_Team_Stats['total_goals_against']/NHL_Team_Stats['game_count']
NHL_Team_Stats
# Out:
#     tricode   pp   pk  ppgf         competition_name    tid  \
# 0       ANA   35   27   9.0         2010 NHL Playoff     21
# 1       BOS  126  116  22.0         2010 NHL Playoff     20
# 2       BUF   48   46  13.0         2010 NHL Playoff     17
# 3       CHI   27   39   6.0         2010 NHL Playoff      6
# 4       DET   59   55   6.0         2010 NHL Playoff     18
# 5       LAK   24   27   5.0         2010 NHL Playoff     41
# 6       MTL   24   31   6.0         2010 NHL Playoff      2
# 7       NSH   49   60   7.0         2010 NHL Playoff     19
# 8       NYR   20   23   1.0         2010 NHL Playoff     28
# 9       PHI   70   69   5.0         2010 NHL Playoff     14
# 10      PHX   19   22   6.0         2010 NHL Playoff     50
# 11      PIT   33   40   4.0         2010 NHL Playoff      8
# 12      SJS   93   88  17.0         2010 NHL Playoff     16
# 13      TBL   80   71  10.0         2010 NHL Playoff     25
# 14      VAN  133  129  21.0         2010 NHL Playoff     53
# 15      WSH   37   34   9.0         2010 NHL Playoff      5
# 16      ANA  401  378  92.0  2010 NHL Regular Season     21
# 17      ATL  338  341  35.0  2010 NHL Regular Season  11366
# 18      BOS  368  370  74.0  2010 NHL Regular Season     20
# 19      BUF  393  364  83.0  2010 NHL Regular Season     17
# 20      CAR  338  427  79.0  2010 NHL Regular Season     66
# 21      CBJ  423  416  45.0  2010 NHL Regular Season     52
# 22      CGY  343  374  90.0  2010 NHL Regular Season     11
# 23      CHI  296  310  93.0  2010 NHL Regular Season      6
# 24      COL  390  338  61.0  2010 NHL Regular Season     22
# 25      DAL  382  416  72.0  2010 NHL Regular Season     46
# 26      DET  325  339  70.0  2010 NHL Regular Season     18
# 27      EDM  425  404  63.0  2010 NHL Regular Season     10
# 28      FLA  304  306  48.0  2010 NHL Regular Season     45
# 29      LAK  354  366  77.0  2010 NHL Regular Season     41
# ..      ...  ...  ...   ...                      ...    ...
# 339     ARI  263  291  47.0  2017 NHL Regular Season     43
# 340     BOS  308  319  72.0  2017 NHL Regular Season     20
# 341     BUF  257  278  16.0  2017 NHL Regular Season     17
# 342     CAR  218  255  51.0  2017 NHL Regular Season     66
# 343     CBJ  246  268  45.0  2017 NHL Regular Season     52
# 344     CGY  353  350  47.0  2017 NHL Regular Season     11
# 345     CHI  268  303  49.0  2017 NHL Regular Season      6
# 346     COL  305  330  67.0  2017 NHL Regular Season     22
# 347     DAL  323  304  56.0  2017 NHL Regular Season     46
# 348     DET  293  278  48.0  2017 NHL Regular Season     18
# 349     EDM  289  255  28.0  2017 NHL Regular Season     10
# 350     FLA  307  328  55.0  2017 NHL Regular Season     45
# 351     LAK  313  289  53.0  2017 NHL Regular Season     41
# 352     MIN  300  270  51.0  2017 NHL Regular Season     35
# 353     MTL  300  278  53.0  2017 NHL Regular Season      2
# 354     NJD  294  289  52.0  2017 NHL Regular Season     29
# 355     NSH  365  334  58.0  2017 NHL Regular Season     19
# 356     NYI  273  282  62.0  2017 NHL Regular Season     51
# 357     NYR  285  278  55.0  2017 NHL Regular Season     28
# 358     OTT  276  287  46.0  2017 NHL Regular Season     32
# 359     PHI  280  321  59.0  2017 NHL Regular Season     14
# 360     PIT  326  317  47.0  2017 NHL Regular Season      8
# 361     SJS  262  287  55.0  2017 NHL Regular Season     16
# 362     STL  259  281  43.0  2017 NHL Regular Season      7
# 363     TBL  319  322  72.0  2017 NHL Regular Season     25
# 364     TOR  256  245  58.0  2017 NHL Regular Season      1
# 365     VAN  299  272  63.0  2017 NHL Regular Season     53
# 366     VGK  257  273  64.0  2017 NHL Regular Season     59
# 367     WPG  307  304  69.0  2017 NHL Regular Season      4
# 368     WSH  327  297  67.0  2017 NHL Regular Season      5
#
#                  team_name  type  game_count  total_games_won  \
# 0            Anaheim Ducks     3           6              2.0
# 1            Boston Bruins     3          24             16.0
# 2           Buffalo Sabres     3           7              3.0
# 3       Chicago Blackhawks     3           7              3.0
# 4        Detroit Red Wings     3          11              7.0
# 5        Los Angeles Kings     3           5              1.0
# 6       Montréal Canadiens     3           7              3.0
# 7      Nashville Predators     3          12              6.0
# 8         New York Rangers     3           5              1.0
# 9      Philadelphia Flyers     3          11              4.0
# 10         Phoenix Coyotes     3           4              0.0
# 11     Pittsburgh Penguins     3           7              3.0
# 12         San Jose Sharks     3          17              9.0
# 13     Tampa Bay Lightning     3          16              9.0
# 14       Vancouver Canucks     3          25             15.0
# 15     Washington Capitals     3           8              4.0
# 16           Anaheim Ducks     2          78             43.5
# 17       Atlanta Thrashers     2          79             34.0
# 18           Boston Bruins     2          82             46.0
# 19          Buffalo Sabres     2          82             43.0
# 20     Carolina Hurricanes     2          82             40.0
# 21   Columbus Blue Jackets     2          81             33.5
# 22          Calgary Flames     2          80             40.5
# 23      Chicago Blackhawks     2          78             41.5
# 24      Colorado Avalanche     2          79             30.5
# 25            Dallas Stars     2          81             42.5
# 26       Detroit Red Wings     2          80             45.5
# 27         Edmonton Oilers     2          80             25.0
# 28        Florida Panthers     2          81             30.0
# 29       Los Angeles Kings     2          81             46.0
# ..                     ...   ...         ...              ...
# 339        Arizona Coyotes     2          79             28.0
# 340          Boston Bruins     2          82             51.0
# 341         Buffalo Sabres     2          76             26.0
# 342    Carolina Hurricanes     2          80             35.5
# 343  Columbus Blue Jackets     2          81             44.0
# 344         Calgary Flames     2          82             37.0
# 345     Chicago Blackhawks     2          80             33.0
# 346     Colorado Avalanche     2          80             42.0
# 347           Dallas Stars     2          79             39.0
# 348      Detroit Red Wings     2          79             29.0
# 349        Edmonton Oilers     2          80             35.0
# 350       Florida Panthers     2          78             40.5
# 351      Los Angeles Kings     2          82             45.0
# 352         Minnesota Wild     2          79             43.0
# 353     Montréal Canadiens     2          79             27.5
# 354      New Jersey Devils     2          80             42.5
# 355    Nashville Predators     2          81             52.0
# 356     New York Islanders     2          81             34.5
# 357       New York Rangers     2          80             33.0
# 358        Ottawa Senators     2          80             25.5
# 359    Philadelphia Flyers     2          81             42.0
# 360    Pittsburgh Penguins     2          82             46.0
# 361        San Jose Sharks     2          80             43.0
# 362        St. Louis Blues     2          79             42.5
# 363    Tampa Bay Lightning     2          80             54.0
# 364    Toronto Maple Leafs     2          79             47.0
# 365      Vancouver Canucks     2          81             30.0
# 366   Vegas Golden Knights     2          81             50.5
# 367          Winnipeg Jets     2          80             51.0
# 368    Washington Capitals     2          81             48.0
#
#      total_goals_for  total_goals_against   win_pct    avg_gf    avg_ga
# 0               19.0                 22.0  0.333333  3.166667  3.666667
# 1               76.0                 48.0  0.666667  3.166667  2.000000
# 2               17.0                 22.0  0.428571  2.428571  3.142857
# 3               22.0                 16.0  0.428571  3.142857  2.285714
# 4               36.0                 27.0  0.636364  3.272727  2.454545
# 5               17.0                 19.0  0.200000  3.400000  3.800000
# 6               17.0                 17.0  0.428571  2.428571  2.428571
# 7               33.0                 33.0  0.500000  2.750000  2.750000
# 8                8.0                 13.0  0.200000  1.600000  2.600000
# 9               29.0                 36.0  0.363636  2.636364  3.272727
# 10               9.0                 18.0  0.000000  2.250000  4.500000
# 11              14.0                 22.0  0.428571  2.000000  3.142857
# 12              50.0                 55.0  0.529412  2.941176  3.235294
# 13              50.0                 39.0  0.562500  3.125000  2.437500
# 14              58.0                 69.0  0.600000  2.320000  2.760000
# 15              21.0                 20.0  0.500000  2.625000  2.500000
# 16             227.0                225.0  0.557692  2.910256  2.884615
# 17             223.0                263.0  0.430380  2.822785  3.329114
# 18             250.0                200.0  0.560976  3.048780  2.439024
# 19             251.0                235.0  0.524390  3.060976  2.865854
# 20             239.0                242.0  0.487805  2.914634  2.951220
# 21             221.0                260.0  0.413580  2.728395  3.209877
# 22             250.0                241.0  0.506250  3.125000  3.012500
# 23             246.0                222.0  0.532051  3.153846  2.846154
# 24             218.0                272.0  0.386076  2.759494  3.443038
# 25             237.0                234.0  0.524691  2.925926  2.888889
# 26             255.0                235.0  0.568750  3.187500  2.937500
# 27             194.0                267.0  0.312500  2.425000  3.337500
# 28             198.0                232.0  0.370370  2.444444  2.864198
# 29             223.0                202.0  0.567901  2.753086  2.493827
# ..               ...                  ...       ...       ...       ...
# 339            204.0                251.0  0.354430  2.582278  3.177215
# 340            274.0                217.0  0.621951  3.341463  2.646341
# 341            182.0                247.0  0.342105  2.394737  3.250000
# 342            227.0                248.0  0.443750  2.837500  3.100000
# 343            242.0                232.0  0.543210  2.987654  2.864198
# 344            223.0                255.0  0.451220  2.719512  3.109756
# 345            225.0                248.0  0.412500  2.812500  3.100000
# 346            251.0                228.0  0.525000  3.137500  2.850000
# 347            226.0                223.0  0.493671  2.860759  2.822785
# 348            212.0                249.0  0.367089  2.683544  3.151899
# 349            231.0                263.0  0.437500  2.887500  3.287500
# 350            237.0                240.0  0.519231  3.038462  3.076923
# 351            242.0                205.0  0.548780  2.951220  2.500000
# 352            248.0                230.0  0.544304  3.139241  2.911392
# 353            205.0                258.0  0.348101  2.594937  3.265823
# 354            240.0                242.0  0.531250  3.000000  3.025000
# 355            268.0                215.0  0.641975  3.308642  2.654321
# 356            261.0                293.0  0.425926  3.222222  3.617284
# 357            234.0                268.0  0.412500  2.925000  3.350000
# 358            220.0                295.0  0.318750  2.750000  3.687500
# 359            251.0                244.0  0.518519  3.098765  3.012346
# 360            271.0                249.0  0.560976  3.304878  3.036585
# 361            257.0                235.0  0.537500  3.212500  2.937500
# 362            223.0                215.0  0.537975  2.822785  2.721519
# 363            293.0                226.0  0.675000  3.662500  2.825000
# 364            268.0                232.0  0.594937  3.392405  2.936709
# 365            219.0                268.0  0.370370  2.703704  3.308642
# 366            269.0                223.0  0.623457  3.320988  2.753086
# 367            274.0                214.0  0.637500  3.425000  2.675000
# 368            255.0                240.0  0.592593  3.148148  2.962963
#
# [369 rows x 15 columns]

# %%
# In the “NHL_Competition” dataframe, the variable “type” indicates the type of competition: type=2 – regular season. 
# Create a dataframe that contains team statistics for games only during regular seasons. 
# Name this dataframe “NHL_Team_R_Stats”. 
# NHL_Team_R_Stats = NHL_Game[NHL_Game['type'] == 2]
# NHL_Team_R_Stats.head()

NHL_Team_R_Stats = NHL_Team_Stats[NHL_Team_Stats['type'] == 2]
NHL_Team_R_Stats.head()
# Out:
#    tricode   pp   pk  ppgf         competition_name    tid  \
# 16     ANA  401  378  92.0  2010 NHL Regular Season     21
# 17     ATL  338  341  35.0  2010 NHL Regular Season  11366
# 18     BOS  368  370  74.0  2010 NHL Regular Season     20
# 19     BUF  393  364  83.0  2010 NHL Regular Season     17
# 20     CAR  338  427  79.0  2010 NHL Regular Season     66
#
#               team_name  type  game_count  total_games_won  total_goals_for  \
# 16        Anaheim Ducks     2          78             43.5            227.0
# 17    Atlanta Thrashers     2          79             34.0            223.0
# 18        Boston Bruins     2          82             46.0            250.0
# 19       Buffalo Sabres     2          82             43.0            251.0
# 20  Carolina Hurricanes     2          82             40.0            239.0
#
#     total_goals_against   win_pct    avg_gf    avg_ga
# 16                225.0  0.557692  2.910256  2.884615
# 17                263.0  0.430380  2.822785  3.329114
# 18                200.0  0.560976  3.048780  2.439024
# 19                235.0  0.524390  3.060976  2.865854
# 20                242.0  0.487805  2.914634  2.951220

# %% [markdown]
# ## Part 2 - Descriptive and Summary Analyses

# %%
# 1. In the “NHL_Game” dataframe, calculate summary statistics for the  “goals_for” variable; 
#    calculate summary statistics for the “goals_against” variable based on whether it is home or away game.
goals_for_stats = NHL_Game['goals_for'].describe()
home_goals_against_stats = NHL_Game[NHL_Game['home_away'] == 'home']['goals_against'].describe()
away_goals_against_stats = NHL_Game[NHL_Game['home_away'] == 'away']['goals_against'].describe()
home_goals_against_stats
# Out:
# count    9253.000000
# mean        2.689830
# std         1.608916
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: goals_against, dtype: float64

# %%
# 2. Create a histogram of the “goals_against” variable by whether the game is home or away 
#    a) Make the color of the histogram green
#    b) Set the number of bins to be 20
#    c) Make sure the two sub-histograms share the same ranges for the x-axis and y-axis.

NHL_Game['home_goals_ag'] = NHL_Game[NHL_Game['home_away'] == 'home']['goals_against']
NHL_Game['away_goals_ag'] = NHL_Game[NHL_Game['home_away'] == 'away']['goals_against']
NHL_Game.hist(column=['home_goals_ag','away_goals_ag'], bins=20, sharex=True, sharey=True, color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8752289ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8750248c88>]],
#       dtype=object)

# %% [markdown]
# ## Part 3 - Correlation Analyses

# %%
# 1. In the “NHL_Team_R_Stats” dataframe, make a scatter plot to depict the relationship between the total number of goals
#    for and the winning percentage. 
#    a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
#    b) Add a regression line to the scatter plot.
#    c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
#    d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

#plt.scatter(NHL_Team_R_Stats['total_goals_for'], NHL_Team_R_Stats['win_pct'])

sns.regplot(x='total_goals_for', y='win_pct', data=NHL_Team_R_Stats,  marker='.')
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.title("Relationship between Goals for and Winning Percentage", fontsize=11)
# Out:
# Text(0.5, 1.0, 'Relationship between Goals for and Winning Percentage')

# %%
# 2. In the “NHL_Team_R_Stats” dataframe, calculate the correlation coefficient between total number of goals for 
#    and winning percentage.
NHL_Team_R_Stats['total_goals_for'].corr(NHL_Team_R_Stats['win_pct'])
# Out:
# 0.31566456280848165

# %%
# 3. Create a scatter plot of the total number of goals for and winning percentage similar to step 1 for 
#    regular season games. In this graph, group observations by “competition_name”.
#    a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
#    b) Add a regression line to the scatter plot.
#    c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
#    d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.



sns.lmplot(x='total_goals_for', y='win_pct', hue='competition_name', data=NHL_Team_R_Stats)
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.title("Relationship between Goals for and Winning Percentage", fontsize=11)
# Out:
# Text(0.5, 1.0, 'Relationship between Goals for and Winning Percentage')

# %%
# 4. For the “NHL_Team_R_Stats” dataframe, delete observations of 2011 and 2012 seasons. 
#    Continue to name the dataframe “NHL_Team_R_Stats”.
NHL_Team_R_Stats = NHL_Team_R_Stats[~NHL_Team_R_Stats['competition_name'].str.contains('2011|2012')]
NHL_Team_R_Stats.head(50)
# Out:
#     tricode   pp   pk  ppgf         competition_name    tid  \
# 16      ANA  401  378  92.0  2010 NHL Regular Season     21
# 17      ATL  338  341  35.0  2010 NHL Regular Season  11366
# 18      BOS  368  370  74.0  2010 NHL Regular Season     20
# 19      BUF  393  364  83.0  2010 NHL Regular Season     17
# 20      CAR  338  427  79.0  2010 NHL Regular Season     66
# 21      CBJ  423  416  45.0  2010 NHL Regular Season     52
# 22      CGY  343  374  90.0  2010 NHL Regular Season     11
# 23      CHI  296  310  93.0  2010 NHL Regular Season      6
# 24      COL  390  338  61.0  2010 NHL Regular Season     22
# 25      DAL  382  416  72.0  2010 NHL Regular Season     46
# 26      DET  325  339  70.0  2010 NHL Regular Season     18
# 27      EDM  425  404  63.0  2010 NHL Regular Season     10
# 28      FLA  304  306  48.0  2010 NHL Regular Season     45
# 29      LAK  354  366  77.0  2010 NHL Regular Season     41
# 30      MIN  375  359  72.0  2010 NHL Regular Season     35
# 31      MTL  399  363  69.0  2010 NHL Regular Season      2
# 32      NJD  281  279  53.0  2010 NHL Regular Season     29
# 33      NSH  315  308  53.0  2010 NHL Regular Season     19
# 34      NYI  449  430  78.0  2010 NHL Regular Season     51
# 35      NYR  362  398  71.0  2010 NHL Regular Season     28
# 36      OTT  394  352  64.0  2010 NHL Regular Season     32
# 37      PHI  379  369  42.0  2010 NHL Regular Season     14
# 38      PHX  350  339  71.0  2010 NHL Regular Season     50
# 39      PIT  457  444  62.0  2010 NHL Regular Season      8
# 40      SJS  348  363  86.0  2010 NHL Regular Season     16
# 41      STL  387  384  39.0  2010 NHL Regular Season      7
# 42      TBL  375  397  43.0  2010 NHL Regular Season     25
# 43      TOR  368  426  46.0  2010 NHL Regular Season      1
# 44      VAN  372  362  97.0  2010 NHL Regular Season     53
# 45      WSH  360  329  69.0  2010 NHL Regular Season      5
# 154     ANA  353  363  67.0  2013 NHL Regular Season     21
# 155     BOS  341  309  69.0  2013 NHL Regular Season     20
# 156     BUF  332  318  40.0  2013 NHL Regular Season     17
# 157     CAR  286  323  51.0  2013 NHL Regular Season     66
# 158     CBJ  360  353  47.0  2013 NHL Regular Season     52
# 159     CGY  300  311  28.0  2013 NHL Regular Season     11
# 160     CHI  290  305  73.0  2013 NHL Regular Season      6
# 161     COL  314  315  23.0  2013 NHL Regular Season     22
# 162     DAL  350  369  58.0  2013 NHL Regular Season     46
# 163     DET  326  311  65.0  2013 NHL Regular Season     18
# 164     EDM  370  365  54.0  2013 NHL Regular Season     10
# 165     FLA  320  323  39.0  2013 NHL Regular Season     45
# 166     LAK  361  355  59.0  2013 NHL Regular Season     41
# 167     MIN  320  322  61.0  2013 NHL Regular Season     35
# 168     MTL  387  385  56.0  2013 NHL Regular Season      2
# 169     NJD  277  245  48.0  2013 NHL Regular Season     29
# 170     NSH  305  310  61.0  2013 NHL Regular Season     19
# 171     NYI  341  356  53.0  2013 NHL Regular Season     51
# 172     NYR  318  353  64.0  2013 NHL Regular Season     28
# 173     OTT  423  372  65.0  2013 NHL Regular Season     32
#
#                  team_name  type  game_count  total_games_won  \
# 16           Anaheim Ducks     2          78             43.5
# 17       Atlanta Thrashers     2          79             34.0
# 18           Boston Bruins     2          82             46.0
# 19          Buffalo Sabres     2          82             43.0
# 20     Carolina Hurricanes     2          82             40.0
# 21   Columbus Blue Jackets     2          81             33.5
# 22          Calgary Flames     2          80             40.5
# 23      Chicago Blackhawks     2          78             41.5
# 24      Colorado Avalanche     2          79             30.5
# 25            Dallas Stars     2          81             42.5
# 26       Detroit Red Wings     2          80             45.5
# 27         Edmonton Oilers     2          80             25.0
# 28        Florida Panthers     2          81             30.0
# 29       Los Angeles Kings     2          81             46.0
# 30          Minnesota Wild     2          80             38.0
# 31      Montréal Canadiens     2          79             43.0
# 32       New Jersey Devils     2          80             37.5
# 33     Nashville Predators     2          80             44.0
# 34      New York Islanders     2          81             29.0
# 35        New York Rangers     2          80             43.0
# 36         Ottawa Senators     2          81             31.0
# 37     Philadelphia Flyers     2          77             44.0
# 38         Phoenix Coyotes     2          79             42.0
# 39     Pittsburgh Penguins     2          81             49.0
# 40         San Jose Sharks     2          81             46.5
# 41         St. Louis Blues     2          77             34.5
# 42     Tampa Bay Lightning     2          81             44.0
# 43     Toronto Maple Leafs     2          82             36.0
# 44       Vancouver Canucks     2          80             53.0
# 45     Washington Capitals     2          81             46.0
# 154          Anaheim Ducks     2          81             53.0
# 155          Boston Bruins     2          82             54.0
# 156         Buffalo Sabres     2          80             21.0
# 157    Carolina Hurricanes     2          80             35.0
# 158  Columbus Blue Jackets     2          81             42.0
# 159         Calgary Flames     2          80             34.5
# 160     Chicago Blackhawks     2          82             46.5
# 161     Colorado Avalanche     2          80             52.0
# 162           Dallas Stars     2          82             40.0
# 163      Detroit Red Wings     2          80             38.0
# 164        Edmonton Oilers     2          80             27.5
# 165       Florida Panthers     2          80             28.0
# 166      Los Angeles Kings     2          80             45.0
# 167         Minnesota Wild     2          82             43.0
# 168     Montréal Canadiens     2          81             45.5
# 169      New Jersey Devils     2          77             33.0
# 170    Nashville Predators     2          81             38.0
# 171     New York Islanders     2          77             30.0
# 172       New York Rangers     2          81             44.0
# 173        Ottawa Senators     2          81             35.5
#
#      total_goals_for  total_goals_against   win_pct    avg_gf    avg_ga
# 16             227.0                225.0  0.557692  2.910256  2.884615
# 17             223.0                263.0  0.430380  2.822785  3.329114
# 18             250.0                200.0  0.560976  3.048780  2.439024
# 19             251.0                235.0  0.524390  3.060976  2.865854
# 20             239.0                242.0  0.487805  2.914634  2.951220
# 21             221.0                260.0  0.413580  2.728395  3.209877
# 22             250.0                241.0  0.506250  3.125000  3.012500
# 23             246.0                222.0  0.532051  3.153846  2.846154
# 24             218.0                272.0  0.386076  2.759494  3.443038
# 25             237.0                234.0  0.524691  2.925926  2.888889
# 26             255.0                235.0  0.568750  3.187500  2.937500
# 27             194.0                267.0  0.312500  2.425000  3.337500
# 28             198.0                232.0  0.370370  2.444444  2.864198
# 29             223.0                202.0  0.567901  2.753086  2.493827
# 30             208.0                237.0  0.475000  2.600000  2.962500
# 31             213.0                203.0  0.544304  2.696203  2.569620
# 32             172.0                199.0  0.468750  2.150000  2.487500
# 33             215.0                189.0  0.550000  2.687500  2.362500
# 34             231.0                271.0  0.358025  2.851852  3.345679
# 35             233.0                197.0  0.537500  2.912500  2.462500
# 36             188.0                251.0  0.382716  2.320988  3.098765
# 37             252.0                222.0  0.571429  3.272727  2.883117
# 38             230.0                225.0  0.531646  2.911392  2.848101
# 39             242.0                195.0  0.604938  2.987654  2.407407
# 40             245.0                214.0  0.574074  3.024691  2.641975
# 41             237.0                230.0  0.448052  3.077922  2.987013
# 42             245.0                243.0  0.543210  3.024691  3.000000
# 43             223.0                259.0  0.439024  2.719512  3.158537
# 44             263.0                182.0  0.662500  3.287500  2.275000
# 45             219.0                201.0  0.567901  2.703704  2.481481
# 154            272.0                217.0  0.654321  3.358025  2.679012
# 155            265.0                181.0  0.658537  3.231707  2.207317
# 156            166.0                254.0  0.262500  2.075000  3.175000
# 157            203.0                227.0  0.437500  2.537500  2.837500
# 158            232.0                218.0  0.518519  2.864198  2.691358
# 159            211.0                241.0  0.431250  2.637500  3.012500
# 160            278.0                231.0  0.567073  3.390244  2.817073
# 161            249.0                209.0  0.650000  3.112500  2.612500
# 162            238.0                232.0  0.487805  2.902439  2.829268
# 163            225.0                231.0  0.475000  2.812500  2.887500
# 164            201.0                269.0  0.343750  2.512500  3.362500
# 165            199.0                273.0  0.350000  2.487500  3.412500
# 166            207.0                175.0  0.562500  2.587500  2.187500
# 167            216.0                215.0  0.524390  2.634146  2.621951
# 168            216.0                206.0  0.561728  2.666667  2.543210
# 169            191.0                206.0  0.428571  2.480519  2.675325
# 170            221.0                248.0  0.469136  2.728395  3.061728
# 171            223.0                264.0  0.389610  2.896104  3.428571
# 172            220.0                199.0  0.543210  2.716049  2.456790
# 173            238.0                271.0  0.438272  2.938272  3.345679

# %%
# 5. In the new “NHL_Team_R_Stats” dataframe, create a scatter plot of total number of goals for and winning percentage.
#    a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
#    b) Add a regression line to the scatter plot.
#    c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
#    d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

sns.regplot(x='total_goals_for', y='win_pct', data=NHL_Team_R_Stats,  marker='.')
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.title("Relationship between Goals for and Winning Percentage", fontsize=11)
# Out:
# Text(0.5, 1.0, 'Relationship between Goals for and Winning Percentage')

# %%
# 6. Calculate the correlation coefficient between total number of goals for and winning percentage in the updated
#    “NHL_Team_R_Stats” dataframe.
NHL_Team_R_Stats['total_goals_for'].corr(NHL_Team_R_Stats['win_pct'])
# Out:
# 0.770625532180144

# %%
# 7. Save dataframes as csv files. 
#    a) Name the updated “NHL_Game” dataframe as “NHL_Game2”.
#    b) Name the “NHL_Team_Stats” dataframe as “NHL_Team_Stats”.
#    c) Name the “NHL_Team_R_Stats” dataframe as “NHL_Team_R_Stats”.
#    d) Make sure to exclude the index as a column in the csv files.

NHL_Game.to_csv("NHL_Game2.csv", index=False)
NHL_Team_Stats.to_csv("NHL_Team_Stats.csv", index=False)
NHL_Team_R_Stats.to_csv("NHL_Team_R_Stats.csv", index=False)

# %% [markdown]
# ## Uncomment this Section once your assignment is complete

# %%
#Save Dataframes as .csv files
#NHL_Game.to_csv("NHL_Game2.csv", index=False)
#NHL_Team_Stats.to_csv("NHL_Team_Stats.csv", index=False)
#NHL_Team_R_Stats.to_csv("NHL_Team_R_Stats.csv", index=False)
